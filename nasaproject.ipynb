# %%
import torch

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv(r'C:/Users/ravi/Desktop/nasaproject/PM_train.txt',header=None, sep=' ')

# %%
data
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20626  100  196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# 20627  100  197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50  1433.58
# 20628  100  198  0.0004  0.0000  100.0  518.67  643.42  1602.46  1428.18
# 20629  100  199 -0.0011  0.0003  100.0  518.67  643.23  1605.26  1426.53
# 20630  100  200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38  1432.14
#
#           9   ...       18      19    20   21    22     23     24       25  \
# ...

# %%
data.columns=['id','cycle','setting1','setting2','setting3','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10','s11','s12','s13','s14','s15','s16','s17','s18','s19','s20','s21','s22','s23']

# %%
data
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70
# 1        1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82
# 2        1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99
# 3        1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79
# 4        1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 20626  100    196   -0.0004   -0.0003     100.0  518.67  643.49  1597.98
# 20627  100    197   -0.0016   -0.0005     100.0  518.67  643.54  1604.50
# 20628  100    198    0.0004    0.0000     100.0  518.67  643.42  1602.46
# 20629  100    199   -0.0011    0.0003     100.0  518.67  643.23  1605.26
# 20630  100    200   -0.0032   -0.0005     100.0  518.67  643.85  1600.38
#
#             s4     s5  ...      s14     s15   s16  s17   s18    s19    s20  \
# ...

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data1=data.drop(['s22', 's23'], axis = 1)

# %%
from sklearn import preprocessing

# %%
set1=data[['s8']]

# %%
set1
# Out:
#             s8
# 0      2388.06
# 1      2388.04
# 2      2388.08
# 3      2388.11
# 4      2388.06
# ...        ...
# 20626  2388.19
# 20627  2388.23
# 20628  2388.24
# 20629  2388.25
# 20630  2388.26
#
# [20631 rows x 1 columns]

# %%
normalized_arr = preprocessing.normalize(set1)
print(normalized_arr)
# Out:
# [[1.]
#  [1.]
#  [1.]
#  ...
#  [1.]
#  [1.]
#  [1.]]

# %%
scaler = preprocessing.MinMaxScaler()

# %%
d = scaler.fit_transform(set1)

# %%
d
# Out:
# array([[0.24242424],
#        [0.21212121],
#        [0.27272727],
#        ...,
#        [0.51515152],
#        [0.53030303],
#        [0.54545455]])

# %%
plt.plot(d)

# %%
cols=['setting1','setting2','setting3','s1','s2','s3','s4','s5','s6','s7','s8','s9','s10','s11','s12','s13','s14','s15','s16','s17','s18','s19','s20','s21','s22','s23']

# %%
newdf=data[cols]

# %%
newdfscaled=scaler.fit_transform(newdf)
# Out:
# C:\Users\ravi\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:373: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\ravi\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:374: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
newdfscaled=pd.DataFrame(newdfscaled,columns=cols)

# %%
newdfscaled
# Out:
#        setting1  setting2  setting3   s1        s2        s3        s4   s5  \
# 0      0.459770  0.166667       0.0  0.0  0.183735  0.406802  0.309757  0.0
# 1      0.609195  0.250000       0.0  0.0  0.283133  0.453019  0.352633  0.0
# 2      0.252874  0.750000       0.0  0.0  0.343373  0.369523  0.370527  0.0
# 3      0.540230  0.500000       0.0  0.0  0.343373  0.256159  0.331195  0.0
# 4      0.390805  0.333333       0.0  0.0  0.349398  0.257467  0.404625  0.0
# ...         ...       ...       ...  ...       ...       ...       ...  ...
# 20626  0.477011  0.250000       0.0  0.0  0.686747  0.587312  0.782917  0.0
# 20627  0.408046  0.083333       0.0  0.0  0.701807  0.729453  0.866475  0.0
# 20628  0.522989  0.500000       0.0  0.0  0.665663  0.684979  0.775321  0.0
# 20629  0.436782  0.750000       0.0  0.0  0.608434  0.746021  0.747468  0.0
# 20630  0.316092  0.083333       0.0  0.0  0.795181  0.639634  0.842167  0.0
#
# ...

# %%
newdfscaled.plot()
# Out:
# <AxesSubplot:>

# %%
newdfscaled['id']=data['id']
newdfscaled['cycle']=data['cycle']

# %%
newdfscaled
# Out:
#        setting1  setting2  setting3   s1        s2        s3        s4   s5  \
# 0      0.459770  0.166667       0.0  0.0  0.183735  0.406802  0.309757  0.0
# 1      0.609195  0.250000       0.0  0.0  0.283133  0.453019  0.352633  0.0
# 2      0.252874  0.750000       0.0  0.0  0.343373  0.369523  0.370527  0.0
# 3      0.540230  0.500000       0.0  0.0  0.343373  0.256159  0.331195  0.0
# 4      0.390805  0.333333       0.0  0.0  0.349398  0.257467  0.404625  0.0
# ...         ...       ...       ...  ...       ...       ...       ...  ...
# 20626  0.477011  0.250000       0.0  0.0  0.686747  0.587312  0.782917  0.0
# 20627  0.408046  0.083333       0.0  0.0  0.701807  0.729453  0.866475  0.0
# 20628  0.522989  0.500000       0.0  0.0  0.665663  0.684979  0.775321  0.0
# 20629  0.436782  0.750000       0.0  0.0  0.608434  0.746021  0.747468  0.0
# 20630  0.316092  0.083333       0.0  0.0  0.795181  0.639634  0.842167  0.0
#
# ...

# %%
dd=data[['id','cycle']]

# %%
dd
# Out:
#         id  cycle
# 0        1      1
# 1        1      2
# 2        1      3
# 3        1      4
# 4        1      5
# ...    ...    ...
# 20626  100    196
# 20627  100    197
# 20628  100    198
# 20629  100    199
# 20630  100    200
#
# [20631 rows x 2 columns]

# %%
data[data['id']==3]
# Out:
#      id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 479   3      1    0.0008    0.0005     100.0  518.67  642.04  1584.20
# 480   3      2   -0.0010    0.0000     100.0  518.67  642.66  1587.04
# 481   3      3    0.0013   -0.0002     100.0  518.67  642.07  1580.75
# 482   3      4    0.0008   -0.0002     100.0  518.67  642.50  1580.12
# 483   3      5    0.0020    0.0004     100.0  518.67  641.97  1581.48
# ..   ..    ...       ...       ...       ...     ...     ...      ...
# 653   3    175   -0.0030    0.0004     100.0  518.67  643.15  1603.74
# 654   3    176   -0.0008    0.0002     100.0  518.67  643.93  1595.61
# 655   3    177   -0.0041   -0.0002     100.0  518.67  643.68  1601.21
# 656   3    178   -0.0010    0.0001     100.0  518.67  643.66  1606.50
# 657   3    179    0.0012    0.0000     100.0  518.67  643.51  1604.80
#
#           s4     s5  ...      s14     s15   s16  s17   s18    s19    s20  \
# ...

# %%
alldummies=[]
ids=[]
life=[]
for i in range(1,101):
    dummydf=data[data['id']==i]
    cls=dummydf['cycle']
    ids.append(i)
    #print(cls)
    lastcycle=dummydf['cycle'].iloc[-1]
    print(lastcycle)
    dummydf['lastcycle']=lastcycle
    dummydf['rul']=dummydf['lastcycle']-dummydf['cycle']
    alldummies.append(dummydf)
    life.append(lastcycle)
# Out:
# 192
# 287
# 179
# 189
# 269
# 188
# 259
# 150
# 201
# 222
# 240
# 170
# 163
# 180
# 207
# 209
# 276
# 195
# 158
# 234
# 195
# 202
# 168
# 147
# 230
# 199
# 156
# 165
# 163
# 194
# 234
# 191
# 200
# 195
# 181
# 158
# 170
# 194
# 128
# 188
# 216
# 196
# 207
# 192
# 158
# 256
# 214
# 231
# 215
# 198
# 213
# 213
# 195
# 257
# 193
# 275
# 137
# 147
# 231
# 172
# 185
# 180
# 174
# 283
# 153
# 202
# 313
# 199
# 362
# 137
# 208
# 213
# 213
# 166
# 229
# 210
# 154
# 231
# 199
# 185
# 240
# 214
# 293
# 267
# 188
# 278
# 178
# 213
# 217
# 154
# 135
# 341
# 155
# 258
# 283
# 336
# 202
# 156
# 185
# 200
# <ipython-input-28-ebfdf96b8354>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dummydf['lastcycle']=lastcycle
# ...

# %%
alldummies[2]
# Out:
#      id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 479   3      1    0.0008    0.0005     100.0  518.67  642.04  1584.20
# 480   3      2   -0.0010    0.0000     100.0  518.67  642.66  1587.04
# 481   3      3    0.0013   -0.0002     100.0  518.67  642.07  1580.75
# 482   3      4    0.0008   -0.0002     100.0  518.67  642.50  1580.12
# 483   3      5    0.0020    0.0004     100.0  518.67  641.97  1581.48
# ..   ..    ...       ...       ...       ...     ...     ...      ...
# 653   3    175   -0.0030    0.0004     100.0  518.67  643.15  1603.74
# 654   3    176   -0.0008    0.0002     100.0  518.67  643.93  1595.61
# 655   3    177   -0.0041   -0.0002     100.0  518.67  643.68  1601.21
# 656   3    178   -0.0010    0.0001     100.0  518.67  643.66  1606.50
# 657   3    179    0.0012    0.0000     100.0  518.67  643.51  1604.80
#
#           s4     s5  ...   s16  s17   s18    s19    s20      s21  s22  s23  \
# ...

# %%
alldf=pd.concat(alldummies)

# %%
alldf
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70
# 1        1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82
# 2        1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99
# 3        1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79
# 4        1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 20626  100    196   -0.0004   -0.0003     100.0  518.67  643.49  1597.98
# 20627  100    197   -0.0016   -0.0005     100.0  518.67  643.54  1604.50
# 20628  100    198    0.0004    0.0000     100.0  518.67  643.42  1602.46
# 20629  100    199   -0.0011    0.0003     100.0  518.67  643.23  1605.26
# 20630  100    200   -0.0032   -0.0005     100.0  518.67  643.85  1600.38
#
#             s4     s5  ...   s16  s17   s18    s19    s20      s21  s22  s23  \
# ...

# %%
plt.scatter(ids,life)

# %% [markdown]
# Exploratory Data Analysis

# %%
data1.isnull().values.any()
# Out:
# False

# %%
newdf
# Out:
#        setting1  setting2  setting3      s1      s2       s3       s4     s5  \
# 0       -0.0007   -0.0004     100.0  518.67  641.82  1589.70  1400.60  14.62
# 1        0.0019   -0.0003     100.0  518.67  642.15  1591.82  1403.14  14.62
# 2       -0.0043    0.0003     100.0  518.67  642.35  1587.99  1404.20  14.62
# 3        0.0007    0.0000     100.0  518.67  642.35  1582.79  1401.87  14.62
# 4       -0.0019   -0.0002     100.0  518.67  642.37  1582.85  1406.22  14.62
# ...         ...       ...       ...     ...     ...      ...      ...    ...
# 20626   -0.0004   -0.0003     100.0  518.67  643.49  1597.98  1428.63  14.62
# 20627   -0.0016   -0.0005     100.0  518.67  643.54  1604.50  1433.58  14.62
# 20628    0.0004    0.0000     100.0  518.67  643.42  1602.46  1428.18  14.62
# 20629   -0.0011    0.0003     100.0  518.67  643.23  1605.26  1426.53  14.62
# 20630   -0.0032   -0.0005     100.0  518.67  643.85  1600.38  1432.14  14.62
#
# ...

# %%
nn=newdf.drop(['s22','s23'],axis=1)

# %%
corr=nn.corr()

# %%
corr
# Out:
#               setting1      setting2  setting3            s1            s2  \
# setting1  1.000000e+00  1.166044e-02       NaN -1.669929e-16  9.029868e-03
# setting2  1.166044e-02  1.000000e+00       NaN -6.876180e-16  7.266242e-03
# setting3           NaN           NaN       NaN           NaN           NaN
# s1       -1.669929e-16 -6.876180e-16       NaN  1.000000e+00  8.476569e-12
# s2        9.029868e-03  7.266242e-03       NaN  8.476569e-12  1.000000e+00
# s3       -5.651101e-03  9.067833e-03       NaN -1.011335e-12  6.026096e-01
# s4        9.543965e-03  1.467284e-02       NaN  5.450136e-14  7.149492e-01
# s5       -3.491551e-18  1.623640e-16       NaN  1.000000e+00  8.475709e-12
# s6       -1.340410e-03  1.435458e-02       NaN  6.935511e-09  1.322425e-01
# s7       -9.437328e-03 -1.667790e-02       NaN  1.765402e-12 -7.021365e-01
# s8       -4.266868e-04  1.328473e-02       NaN -1.911824e-10  6.623250e-01
# ...

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Anomoly detection

# %%
plt.boxplot(data['s9'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17d8f1c93d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x17d8f1b4f40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17d8abc24f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x17d8f26d490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17d8f26d730>],
#  'means': []}

# %%
data['s9'].plot()
# Out:
# <AxesSubplot:>

# %%
data['s9']
# Out:
# 0        9046.19
# 1        9044.07
# 2        9052.94
# 3        9049.48
# 4        9055.15
#           ...
# 20626    9065.52
# 20627    9065.11
# 20628    9065.90
# 20629    9073.72
# 20630    9061.48
# Name: s9, Length: 20631, dtype: float64

# %%
data
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70
# 1        1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82
# 2        1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99
# 3        1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79
# 4        1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 20626  100    196   -0.0004   -0.0003     100.0  518.67  643.49  1597.98
# 20627  100    197   -0.0016   -0.0005     100.0  518.67  643.54  1604.50
# 20628  100    198    0.0004    0.0000     100.0  518.67  643.42  1602.46
# 20629  100    199   -0.0011    0.0003     100.0  518.67  643.23  1605.26
# 20630  100    200   -0.0032   -0.0005     100.0  518.67  643.85  1600.38
#
#             s4     s5  ...      s14     s15   s16  s17   s18    s19    s20  \
# ...

# %%
#data = [1, 2, 2, 2, 3, 1, 1, 15, 2, 2, 2, 3, 1, 1, 2]
s9=data['s2']

# %%
mean = np.mean(s9)

std = np.std(data)
print('mean of the dataset is', mean)
print('std. deviation is', std)
threshold = 8
outlier = []
for i in data:
    z = (i-mean)/std
    
    if z > threshold:
        outlier.append(i)
        
print('outlier in dataset is', outlier)
# Out:
# mean of the dataset is 642.6809335466004
# std. deviation is id          2.922692e+01
# cycle       6.887932e+01
# setting1    2.187260e-03
# setting2    2.930550e-04
# setting3    0.000000e+00
# s1          6.536993e-11
# s2          5.000412e-01
# s3          6.131001e+00
# s4          9.000387e+00
# s5          3.394618e-12
# s6          1.388951e-03
# s7          8.850708e-01
# s8          7.098376e-02
# s9          2.208234e+01
# s10         4.660716e-13
# s11         2.670809e-01
# s12         7.375355e-01
# s13         7.191717e-02
# s14         1.907571e+01
# s15         3.750413e-02
# s16         1.556394e-14
# s17         1.548725e+00
# s18         0.000000e+00
# s19         0.000000e+00
# s20         1.807420e-01
# s21         1.082483e-01
# s22                  NaN
# s23                  NaN
# dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...

# %%
print(mean)
# Out:
# 642.6809335466004

# %%
data
# Out:
#         id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0        1      1   -0.0007   -0.0004     100.0  518.67  641.82  1589.70
# 1        1      2    0.0019   -0.0003     100.0  518.67  642.15  1591.82
# 2        1      3   -0.0043    0.0003     100.0  518.67  642.35  1587.99
# 3        1      4    0.0007    0.0000     100.0  518.67  642.35  1582.79
# 4        1      5   -0.0019   -0.0002     100.0  518.67  642.37  1582.85
# ...    ...    ...       ...       ...       ...     ...     ...      ...
# 20626  100    196   -0.0004   -0.0003     100.0  518.67  643.49  1597.98
# 20627  100    197   -0.0016   -0.0005     100.0  518.67  643.54  1604.50
# 20628  100    198    0.0004    0.0000     100.0  518.67  643.42  1602.46
# 20629  100    199   -0.0011    0.0003     100.0  518.67  643.23  1605.26
# 20630  100    200   -0.0032   -0.0005     100.0  518.67  643.85  1600.38
#
#             s4     s5  ...      s14     s15   s16  s17   s18    s19    s20  \
# ...

# %%
plt.scatter(s9.index,s9)
